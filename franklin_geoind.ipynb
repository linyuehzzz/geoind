# %% [markdown]
# Prepare data

# %%
# import pandas as pd
# import numpy as np

# n1, n2, n3, n4, n5 = 8, 2, 2, 63, 2
# filename_pums = 'data/franklin/franklin_pums10.csv'

# # prepare pums
# pums = pd.read_csv(filename_pums)
# pumaids = [*set(pums['PUMA'].to_list())]
# pumaids.sort()

# df = pums.groupby(['PUMA', 'RAC1P', 'SEX']).size()

# with open('data/franklin/franklin_r2s2.csv', 'w') as f:
#     for id in pumaids:
#         cnt = df.loc[(id, 2, 2)] # black females
#         f.write(str(id) + ',' + str(cnt) + '\n')

# %%
import geopandas as gpd
import pandas as pd

gdf_hh = gpd.read_file('data/franklin/franklin_households_all.shp')
df_puma = pd.read_csv('data/franklin/franklin_r2s2.csv')
df_puma['PUMAID'] = df_puma['PUMAID'].astype(str).str.zfill(5)

frames = []
for idx, row in df_puma.iterrows():
    pumaid = row['PUMAID']
    cnt = row['COUNT']
    gdf = gdf_hh[gdf_hh['PUMACE10'] == pumaid]
    sample = gdf.sample(n=cnt)
    frames.append(sample)

results = pd.concat(frames)
results.to_file('data/franklin/franklin_sample.shp')

# %% [markdown]
# Read data

# %%
import geopandas as gpd
from shapely.geometry import Point

gdf1 = gpd.read_file('data/franklin/franklin_sample.shp')
gdf2 = gpd.read_file('data/franklin/franklin_households_all.shp')
# Out:
# c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# Model input

# %%
from sklearn.neighbors import BallTree
import pickle

k_neighbors = 31
def get_nearest(src_points, candidates, k_neighbors=10):
    """
    Find nearest neighbors for all source points from a set of candidate points
    modified from: https://automating-gis-processes.github.io/site/notebooks/L3/nearest-neighbor-faster.html
    """
    
    # Create tree from the candidate points
    tree = BallTree(candidates, leaf_size=15, metric='euclidean')

    # Find closest points and distances
    distances, indices = tree.query(src_points, k=k_neighbors)

    # Return indices and distances
    return indices, distances

in_pts = [(x,y) for x,y in zip(gdf1.geometry.x , gdf1.geometry.y)]
qry_pts =  [(x,y) for x,y in zip(gdf2.geometry.x , gdf2.geometry.y)]
X, X_dis = get_nearest(in_pts, qry_pts, k_neighbors)
pickle.dump(X, open('data/franklin/franklin_buff_k' + str(k_neighbors-1) + '.pickle', "wb"))
pickle.dump(X_dis, open('data/franklin/franklin_buff_dis_k' + str(k_neighbors-1) + '.pickle', "wb"))

X, X_dis
# Out:
# (array([[ 22654, 119781,  95314, ...,  97428,  27877,  95629],
#         [ 48170,  70589,  45514, ...,  27543,  64190,  11695],
#         [217070, 185480, 316065, ..., 396085, 321488, 427653],
#         ...,
#         [ 89941,  37714,  85889, ...,  62263,  72847,  29326],
#         [253103, 432025, 192989, ..., 109124, 301018, 168170],
#         [369054, 172644, 276628, ..., 137615, 424484, 238331]], dtype=int64),
#  array([[  0.        ,  15.81209221,  27.85561867, ..., 117.21184408,
#          123.63197443, 124.57203299],
#         [  0.        ,  26.45222488,  29.18357645, ..., 123.79526372,
#          125.11478124, 126.66514572],
#         [  0.        ,   9.97868952,  13.18986719, ...,  79.08705572,
#           79.1685651 ,  79.54023927],
#         ...,
#         [  0.        ,  33.00353501,  51.66590177, ..., 130.30021713,
#          130.824802  , 133.23307524],
#         [  0.        ,  22.88552008,  23.6435183 , ..., 130.59100028,
#          130.59100028, 131.78119595],
#         [  0.        ,  23.99601557,  27.07617383, ..., 117.33219738,
#          117.92064186, 120.00176294]]))

# %%
import pickle
import pandas as pd

k_neighbors = 10
with open('data/franklin/franklin_buff_k' + str(k_neighbors) + '.pickle', "rb") as f:
    object = pickle.load(f)
    
df = pd.DataFrame(object)
df.to_csv(r'data/franklin/franklin_buff_k' + str(k_neighbors) + '.csv')

# %%
# epsilon
eps = 0.01

# number of sample households
M = len(gdf1)

# %% [markdown]
# Optimization

# %%
from gurobipy import Model, GRB, LinExpr, quicksum
import numpy as np
import csv

with open('data/franklin/franklin_prob.csv', 'w', newline='') as f1:
    wr1 = csv.writer(f1)
    with open('data/franklin/franklin_prob_obj.csv', 'w', newline='') as f2:
        wr2 = csv.writer(f2)

        for k in range(M):
            # initialize model
            m = Model('td')


            # add objective function
            obj = LinExpr()

            # add decision variables and objective function
            p = {}     ## decision vairable
            d = np.zeros((k_neighbors, k_neighbors))
            for i in range(k_neighbors):
                for j in range(k_neighbors):
                    if j != i:
                    # objective
                        d[i, j] = gdf2.iloc[X[k, i]].geometry.distance(gdf2.iloc[X[k, j]].geometry)
                        p[i, j] = m.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1, name="p_%d_%d"%(i, j))
                        obj += p[i, j] * d[i, j]

            # add constraints
            for i1 in range(k_neighbors):
                for j in range(k_neighbors):
                    for i2 in range(k_neighbors):
                        if j != i1 and j != i2:
                            m.addConstr(p[i1, j] <= np.exp(eps * d[i1, i2]) * p[i2, j])
            for i in range(k_neighbors):
                tmp = [j for j in range(k_neighbors) if j != i]
                m.addConstr(quicksum(p[i, j] for j in tmp) == 1)
            
            m.setObjective(obj, GRB.MINIMIZE)

            m.update()
            m.optimize()

            # write prob values
            prob_values = [k]
            var_values = [var.X for var in m.getVars() if 'p_0_' == str(var.VarName[0:4])]
            prob_values.extend(var_values)
            wr1.writerow(prob_values)

            # write objective values
            obj = m.getObjective().getValue()
            wr2.writerow([k, obj])
            print(k)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-23
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x32e91e47
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8487720e+02   6.200000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 3
#      132    4.1617484e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 132 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  4.161748377e+02
# 0
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x81c75359
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5375951e+02   5.000000e+01   0.000000e+00      0s
#      121    4.8554232e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 121 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.855423153e+02
# 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xc40e4097
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [9e+00, 6e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.5487090e+01   6.200000e+01   0.000000e+00      0s
#      133    2.3962550e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 133 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.396254994e+02
# 2
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xa949aefa
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0725194e+02   5.450000e+01   0.000000e+00      0s
#      128    4.1817719e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 128 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.181771937e+02
# 3
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x2875ad3e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2544454e+02   7.600000e+01   0.000000e+00      0s
#      185    2.4290317e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 185 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.429031655e+02
# 4
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x704d6020
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6660429e+02   2.500000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      125    7.0753771e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 125 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.075377092e+02
# 5
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x3164cf0c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2239735e+02   4.750000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      109    4.8706509e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 109 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.870650852e+02
# 6
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x5c640a5d
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3411574e+02   3.950000e+01   0.000000e+00      0s
#       86    5.7083362e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 86 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.708336190e+02
# 7
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xdaae0cfa
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2452865e+02   1.975000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       93    7.3195747e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 93 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.319574711e+02
# 8
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xde2197d5
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9336549e+02   4.150000e+01   0.000000e+00      0s
#      109    6.1194283e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 109 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.119428271e+02
# 9
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xbc31e255
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.1657439e+02   4.762500e+01   0.000000e+00      0s
#      108    9.5103091e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 108 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.510309050e+02
# 10
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x3cfdee07
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+01, 9e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6954267e+02   6.400000e+01   0.000000e+00      0s
#      150    4.1712877e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 150 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.171287702e+02
# 11
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x0cdf9572
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7125628e+02   3.300000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#      131    6.6210889e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 131 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.621088921e+02
# 12
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xff35df52
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [4e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8664494e+01   7.600000e+01   0.000000e+00      0s
#      179    2.0567532e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 179 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.056753233e+02
# 13
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x187053c3
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7967927e+02   5.050000e+01   0.000000e+00      0s
#      124    4.5129367e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 124 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.512936675e+02
# 14
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x5c82c152
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.6131195e+02   3.612500e+01   0.000000e+00      0s
#      101    8.4718641e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 101 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.471864062e+02
# 15
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xe62b8f46
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.3085400e+01   7.600000e+01   0.000000e+00      0s
#      198    1.5085443e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 198 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.508544266e+02
# 16
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x75006397
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [8e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4418238e+02   6.100000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      143    3.8237919e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 143 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.823791949e+02
# 17
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x86682afc
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9863932e+02   4.225000e+01   0.000000e+00      0s
#      128    5.5031776e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 128 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.503177567e+02
# 18
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x87b16a6e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.7290798e+01   7.000000e+01   0.000000e+00      0s
#      177    2.2298270e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 177 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.229827013e+02
# 19
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x78c9c303
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [7e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9875161e+02   4.800000e+01   0.000000e+00      0s
#      147    4.7914809e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 147 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.791480934e+02
# 20
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x4d7c61c6
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7710809e+02   2.000000e+01   0.000000e+00      0s
#      103    8.0692586e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 103 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.069258610e+02
# 21
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x1f1dbc67
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [3e+01, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.9857893e+02   7.400000e+01   0.000000e+00      0s
#       80    1.1628497e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 80 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.162849694e+03
# 22
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x59fb9035
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [5e+00, 8e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3915818e+02   5.350000e+01   0.000000e+00      0s
#      117    3.8257067e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 117 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.825706712e+02
# 23
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x60576ab8
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [6e+00, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.8193174e+01   7.250000e+01   0.000000e+00      0s
#      137    2.9528812e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 137 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.952881233e+02
# 24
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x3b9fa79e
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9023574e+02   5.950000e+01   0.000000e+00      0s
#      149    4.1557472e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 149 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.155747198e+02
# 25
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x4bc38e6d
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8783254e+02   2.300000e+01   0.000000e+00      0s
#      124    7.5254275e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 124 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.525427487e+02
# 26
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x17d7870b
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8500925e+02   4.275000e+01   0.000000e+00      0s
#      107    6.2361103e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 107 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.236110304e+02
# 27
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x47a845e4
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.7768377e+02   4.125000e+01   0.000000e+00      0s
#       75    1.0961295e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 75 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.096129512e+03
# 28
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x5629494c
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [2e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1820655e+02   3.475000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      125    6.2274135e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 125 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.227413452e+02
# 29
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x696dccb4
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [2e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7273448e+02   2.300000e+01   0.000000e+00      0s
#      115    7.1356148e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 115 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.135614849e+02
# 30
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xc81a54e9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [9e-02, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 540 rows and 33 columns
# Presolve time: 0.00s
# Presolved: 280 rows, 57 columns, 630 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0883888e+01   3.200000e+01   0.000000e+00      0s
#      103    1.1722348e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 103 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.172234822e+02
# 31
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x18ff1d89
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.6905839e+02   3.137500e+01   0.000000e+00      0s
#      105    7.7173727e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 105 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.717372701e+02
# 32
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x489e9748
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [4e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0392499e+01   5.900000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      150    3.2998357e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 150 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.299835665e+02
# 33
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x5fd50a65
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2177905e+02   3.775000e+01   0.000000e+00      0s
#       69    4.7445281e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 69 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.744528102e+02
# 34
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x64a6860a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4530226e+02   4.900000e+01   0.000000e+00      0s
#      121    4.9687624e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 121 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.968762356e+02
# 35
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x4555a060
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [2e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6690777e+02   2.500000e+01   0.000000e+00      0s
#      116    5.5599665e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 116 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.559966487e+02
# 36
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xabc11d89
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [4e+00, 6e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1537385e+02   7.600000e+01   0.000000e+00      0s
#      147    2.9564054e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 147 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.956405421e+02
# 37
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x7ff9e396
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 810 rows and 80 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 10 columns, 90 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.000000e+00   0.000000e+00      0s
#        9    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# 38
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xcdbb9173
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6342244e+02   3.775000e+01   0.000000e+00      0s
#      120    5.6374429e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 120 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.637442922e+02
# 39
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x0e38fed2
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [5e+00, 6e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3487593e+01   7.200000e+01   0.000000e+00      0s
#      160    1.8547238e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 160 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.854723752e+02
# 40
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xced80796
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0999263e+02   6.100000e+01   0.000000e+00      0s
#      114    4.5279784e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 114 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.527978431e+02
# 41
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x1e29f8f4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.0295046e+01   5.900000e+01   0.000000e+00      0s
#      171    1.5032484e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 171 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.503248433e+02
# 42
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x6b527ad9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 696 rows and 51 columns
# Presolve time: 0.00s
# Presolved: 124 rows, 39 columns, 318 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6095123e+01   1.500000e+01   0.000000e+00      0s
#       63    1.1087012e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 63 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.108701192e+02
# 43
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x0238e7c4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2427476e+01   7.200000e+01   0.000000e+00      0s
#      189    1.7476132e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 189 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.747613206e+02
# 44
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x2f2d9762
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9290389e+02   2.987500e+01   0.000000e+00      0s
#       95    8.0411389e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 95 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.041138922e+02
# 45
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x14050245
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6807000e+02   5.700000e+01   0.000000e+00      0s
#      118    4.4730974e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 118 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.473097439e+02
# 46
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x980fae46
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [4e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.9201268e+01   7.400000e+01   0.000000e+00      0s
#      147    2.5299262e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 147 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.529926223e+02
# 47
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x230b12c5
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [9e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6859953e+02   6.250000e+01   0.000000e+00      0s
#      145    3.4174518e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 145 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.417451848e+02
# 48
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x5847d8fa
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 348 rows and 17 columns
# Presolve time: 0.00s
# Presolved: 472 rows, 73 columns, 1014 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8683765e+01   4.900000e+01   0.000000e+00      0s
#      122    2.3881161e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 122 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.388116129e+02
# 49
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xd98dc8fa
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5492001e+02   5.050000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#      104    3.6866512e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 104 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.686651197e+02
# 50
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xc010d048
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4077960e+02   5.400000e+01   0.000000e+00      0s
#      136    4.9031141e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 136 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.903114064e+02
# 51
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xfb12080e
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5649085e+02   6.850000e+01   0.000000e+00      0s
#      136    3.8035523e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 136 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.803552291e+02
# 52
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xf1b7abaa
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8059209e+02   3.500000e+01   0.000000e+00      0s
#      113    6.4747940e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 113 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.474793986e+02
# 53
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x9bef4f6b
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9402639e+02   3.500000e+01   0.000000e+00      0s
#      115    6.4778325e+02   0.000000e+00   0.000000e+00      0s
#
# ...
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x69f0b692
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2285377e+02   4.750000e+01   0.000000e+00      0s
#       91    5.2240573e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 91 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.224057273e+02
# 1724
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xdcb1234d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6065920e+02   5.950000e+01   0.000000e+00      0s
#      119    4.1043212e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 119 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  4.104321200e+02
# 1725
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x7ff9e396
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 810 rows and 80 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 10 columns, 90 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.000000e+00   0.000000e+00      0s
#        9    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# 1726
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xe36b1e1a
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8175752e+02   3.700000e+01   0.000000e+00      0s
#      107    5.2884583e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 107 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.288458342e+02
# 1727
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x0e941efb
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9668191e+02   3.100000e+01   0.000000e+00      0s
#      116    6.1732233e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 116 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.173223302e+02
# 1728
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xbeeb5a71
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4108066e+02   5.600000e+01   0.000000e+00      0s
#      152    4.0398047e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 152 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.039804693e+02
# 1729
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xebae92fa
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0723115e+02   3.550000e+01   0.000000e+00      0s
#       98    5.5754902e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 98 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.575490158e+02
# 1730
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xdd05bc4a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5954726e+02   4.050000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 4
#      141    4.9681088e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 141 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.968108763e+02
# 1731
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xd479de1e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3866671e+01   7.600000e+01   0.000000e+00      0s
#      185    9.1662035e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 185 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.166203539e+01
# 1732
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xa710eae4
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8682119e+02   4.150000e+01   0.000000e+00      0s
#      170    5.0273749e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 170 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  5.027374920e+02
# 1733
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x88f9c273
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 218 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 602 rows, 82 columns, 1274 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8956684e+02   5.050000e+01   0.000000e+00      0s
#       96    4.2200126e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 96 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.220012626e+02
# 1734
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x8f801ea4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7527130e+01   8.000000e+01   0.000000e+00      0s
#      147    1.1251834e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 147 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.125183380e+02
# 1735
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0xaa5a881c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5962143e+02   5.150000e+01   0.000000e+00      0s
#      139    4.4491837e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 139 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.449183676e+02
# 1736
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: AMD Ryzen 5 5600X 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 820 rows, 90 columns and 1530 nonzeros
# Model fingerprint: 0x396a19d8
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [2e+01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 90 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 730 rows, 90 columns, 1530 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6481116e+02   3.925000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       98    5.3559157e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 98 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.355915710e+02
# 1737
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 25
#      22 for j in range(k_neighbors):
#      23     if j != i:
#      24     # objective
# ---> 25         d[i, j] = gdf2.iloc[X[k, i]].geometry.distance(gdf2.iloc[X[k, j]].geometry)
#      26         p[i, j] = m.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1, name="p_%d_%d"%(i, j))
#      27         obj += p[i, j] * d[i, j]
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexing.py:931, in _LocationIndexer.__getitem__(self, key)
#     928 axis = self.axis or 0
#     930 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexing.py:1568, in _iLocIndexer._getitem_axis(self, key, axis)
#    1565 # validate the location
#    1566 self._validate_integer(key, axis)
# -> 1568 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:3379, in DataFrame._ixs(self, i, axis)
#    3377 # irow
#    3378 if axis == 0:
# -> 3379     new_values = self._mgr.fast_xs(i)
#    3381     # if we are a copy, mark as such
#    3382     copy = isinstance(new_values, np.ndarray) and new_values.base is None
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py:970, in BlockManager.fast_xs(self, loc)
#     966 for blk in self.blocks:
#     967     # Such assignment may incorrectly coerce NaT to None
#     968     # result[blk.mgr_locs] = blk._slice((slice(None), loc))
#     969     for i, rl in enumerate(blk.mgr_locs):
# --> 970         result[rl] = blk.iget((i, loc))
#     972 if isinstance(dtype, ExtensionDtype):
#     973     result = dtype.construct_array_type()._from_sequence(result, dtype=dtype)
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py:1409, in ExtensionBlock.iget(self, col)
#    1407             raise NotImplementedError(col)
#    1408         return self.values[[loc]]
# -> 1409     return self.values[loc]
#    1410 else:
#    1411     if col != 0:
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\geopandas\array.py:363, in GeometryArray.__getitem__(self, idx)
#     361 def __getitem__(self, idx):
#     362     if isinstance(idx, numbers.Integral):
# --> 363         return _geom_to_shapely(self.data[idx])
#     364     # array-like, slice
#     365     # validate and convert IntegerArray/BooleanArray
#     366     # to numpy array, pass-through non-array-like indexers
#     367     idx = pd.api.indexers.check_array_indexer(self, idx)
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\geopandas\array.py:116, in _geom_to_shapely(geom)
#     114     return geom
#     115 else:
# --> 116     return vectorized._pygeos_to_shapely(geom)
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\geopandas\_vectorized.py:87, in _pygeos_to_shapely(geom)
#      85     return shapely.wkt.loads("POINT EMPTY")
#      86 else:
# ---> 87     return shapely.wkb.loads(pygeos.to_wkb(geom))
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\shapely\wkb.py:23, in loads(data, hex)
#      21     return reader.read_hex(data)
#      22 else:
# ---> 23     return reader.read(data)
#
# File c:\Users\Yue\AppData\Local\Programs\Python\Python38\lib\site-packages\shapely\geos.py:460, in WKBReader.read(self, data)
#     458 def read(self, data):
#     459     """Returns geometry from WKB"""
# --> 460     geom = self._lgeos.GEOSWKBReader_read(
#     461         self._reader, c_char_p(data), c_size_t(len(data)))
#     462     if not geom:
#     463         raise WKBReadingError(
#     464             "Could not create geometry because of errors "
#     465             "while reading input.")
#
# KeyboardInterrupt:

# %% [markdown]
# Impacts of input parameters

# %%
import pandas as pd

k_neighbors_all = [10, 20, 30]
eps_all = [0.1, 0.01, 0.001, 0.0001]

with open('data/franklin/sols/franklin_prob_obj_all.csv', 'w') as fw:
    fw.write('eps,k,sql\n')
    fw.flush()

    for eps in eps_all:
        for k_neighbors in k_neighbors_all:
            obj = pd.read_csv('data/franklin/sols/franklin_prob_obj_eps' + str(eps) + "_k" + str(k_neighbors) + '.csv', header=None, index_col=0)
            obj_mean = obj[1].mean()
            fw.write(str(eps) + ',' + str(k_neighbors) + ',' + str(obj_mean) + '\n')

# %%
import pandas as pd
import numpy as np
import random

k_neighbors_all = [10, 20, 30]
eps_all = [0.1, 0.01, 0.001, 0.0001]

for k_neighbors in k_neighbors_all:
    for eps in eps_all:
        masked_locs = []
        buffer = pickle.load(open('data/franklin/franklin_buff_k' + str(k_neighbors) + '.pickle', "rb"))
        prob = pd.read_csv('data/franklin/sols/franklin_prob_eps' + str(eps) + "_k" + str(k_neighbors) + '.csv', header=None, index_col=0)

        for idx, row in prob.iterrows():
            locs = buffer[idx]
            locs = np.delete(locs, 0)
            x = random.choices(locs, weights=tuple(row.tolist()), k=1)[0]
            masked_locs.append(x)
        gdf = gdf2.iloc[masked_locs]
        gdf.to_file('data/franklin/sols/shp/franklin_masked_eps' + str(eps) + "_k" + str(k_neighbors) + '.shp')

# %% [markdown]
# Comparative analysis with randomized location swapping

# %% [markdown]
# (1) Expected distance displaced

# %%
def random_edd(buffer_dis):
    edd_random = []
    for row in buffer_dis:
        edd_random.append(np.mean(row))
    return sum(edd_random) / len(edd_random)

def gm_edd(prob, buffer_dis):
    edd_gm = []
    for idx, row in prob.iterrows():
        edd_gm.append(np.dot(buffer_dis[idx], row.tolist()))
    return sum(edd_gm) / len(edd_gm)

# %%
import pandas as pd
import pickle
import numpy as np

k_neighbors_all = [10, 20, 30]
eps_all = [0.1, 0.01, 0.001, 0.0001]

with open('data/franklin/sols/franklin_edd_all.csv', 'w') as fw:
    fw.write('method,eps,k,edd\n')
    fw.flush()

    for k_neighbors in k_neighbors_all:
        buffer_dis = pickle.load(open('data/franklin/franklin_buff_dis_k' + str(k_neighbors) + '.pickle', "rb"))
        buffer_dis = np.delete(buffer_dis, 0, 1)

        # random
        edd_random = random_edd(buffer_dis)
        fw.write('random,,' + str(k_neighbors) + ',' + str(edd_random) + '\n')
        print('edd_random:', edd_random)
        
        # gm
        for eps in eps_all:
            prob = pd.read_csv('data/franklin/sols/franklin_prob_eps' + str(eps) + "_k" + str(k_neighbors) + '.csv', header=None, index_col=0)
            edd_gm = gm_edd(prob, buffer_dis)
            fw.write('gm,' + str(eps) + ',' + str(k_neighbors) + ',' + str(edd_gm) + '\n')
            print('edd_gm:', edd_gm)
# Out:
# edd_random: 43.88582553571073
# edd_gm: 18.863580469408273
# edd_gm: 26.96121594251074
# edd_gm: 41.12635560596364
# edd_gm: 43.62456836438404
# edd_random: 62.1246197554136
# edd_gm: 19.411952703583697
# edd_gm: 34.06705612220797
# edd_gm: 51.812218869608856
# edd_gm: 61.12443555839775
# edd_random: 76.6924851540253
# edd_gm: 19.534956963771965
# edd_gm: 42.49507453171577
# edd_gm: 55.82398522218376
# edd_gm: 74.38384392099407

# %% [markdown]
# (2) Average nearest neighbors

# %%
from pointpats import PointPattern
import random
import numpy as np

def origin_ann(gdf):
    points = np.array(np.stack([gdf.geometry.x, gdf.geometry.y], axis=1))
    pp = PointPattern(points)
    return pp.mean_nnd


def random_ann(buffer, ann_origin, T=100):
    ann = []
    for t in range(T):
        masked_locs = []
        for locs in buffer:
            locs = np.delete(locs, 0)
            x = random.choice(locs)
            masked_locs.append(x)
        gdf = gdf2.iloc[masked_locs]
        points = np.array(np.stack([gdf.geometry.x, gdf.geometry.y], axis=1))
        pp = PointPattern(points)
        ann.append(pp.mean_nnd)
    return sum(ann) / len(ann) - ann_origin


def gm_ann(prob, buffer, ann_origin, T=100):
    ann = []
    for t in range(T):
        masked_locs = []
        for idx, row in prob.iterrows():
            locs = buffer[idx]
            locs = np.delete(locs, 0)
            x = random.choices(locs, weights=tuple(row.tolist()), k=1)[0]
            masked_locs.append(x)
        gdf = gdf2.iloc[masked_locs]
        points = np.array(np.stack([gdf.geometry.x, gdf.geometry.y], axis=1))
        pp = PointPattern(points)
        ann.append(pp.mean_nnd)
    return sum(ann) / len(ann) - ann_origin

# %%
import pandas as pd
import pickle

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

ann_origin = origin_ann(gdf1)
print('ann_origin:', ann_origin)

k_neighbors_all = [10, 20, 30]
eps_all = [0.1, 0.01, 0.001, 0.0001]
T = 100

with open('data/franklin/sols/franklin_ann_all.csv', 'w') as fw:
    fw.write('method,eps,k,ann\n')
    fw.write('origin,,' + str(ann_origin) + '\n')
    fw.flush()
    
    for k_neighbors in k_neighbors_all:
        buffer = pickle.load(open('data/franklin/franklin_buff_k' + str(k_neighbors) + '.pickle', "rb"))
        ann_random = random_ann(buffer, ann_origin, T)
        fw.write('random,,' + str(k_neighbors) + ',' + str(ann_random) + '\n')
        print('ann_random:', ann_random)
        
        for eps in eps_all:
            prob = pd.read_csv('data/franklin/sols/franklin_prob_eps' + str(eps) + "_k" + str(k_neighbors) + '.csv', header=None, index_col=0)
            ann_gm = gm_ann(prob, buffer, ann_origin, T)
            fw.write('gm,' + str(eps) + ',' + str(k_neighbors) + ',' + str(ann_gm) + '\n')
            print('ann_gm:', ann_gm)
# Out:
# ann_origin: 193.87017948022927
# ann_random: -4.520564948909197
# ann_gm: -1.3312523108770336
# ann_gm: -4.486357144666215
# ann_gm: -5.072479350270669
# ann_gm: -4.538217193746192
# ann_random: -6.751801306286069
# ann_gm: -1.3272165283506183
# ann_gm: -7.480518932720031
# ann_gm: -9.22015204110619
# ann_gm: -7.08152103281995
# ann_random: -8.262555654157438
# ann_gm: -1.9926870443501912
# ann_gm: -10.415538137786541
# ann_gm: -12.269262393306406
# ann_gm: -9.74583606741038

# %% [markdown]
# (3) Cluster detection

# %%
from sklearn.cluster import DBSCAN
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

X = np.array(np.stack([gdf1.geometry.x, gdf1.geometry.y], axis=1))
db = DBSCAN(eps=1000, min_samples=30).fit(X)
labels = db.labels_
gdf = gdf1.copy()
gdf['db_origin'] = labels
gdf.to_file('data/franklin/franklin_sample_db.shp')

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
# Out:
# Estimated number of clusters: 12
# Estimated number of noise points: 1969

# %%
import random
from sklearn import metrics
from sklearn.cluster import DBSCAN
import numpy as np

def random_db(buffer, labels, T=100):
    precision_all, recall_all, f1_score_all = [], [], []
    for t in range(T):
        masked_locs = []
        for locs in buffer:
            locs = np.delete(locs, 0)
            x = random.choice(locs)
            masked_locs.append(x)
        gdf = gdf2.iloc[masked_locs]
        points = np.array(np.stack([gdf.geometry.x, gdf.geometry.y], axis=1))
        db = DBSCAN(eps=500, min_samples=5).fit(points)
        preds = db.labels_
        preds_binary = [0 if i == -1 else 1 for i in preds]

        precision = metrics.precision_score(labels, preds_binary, average='weighted')
        recall = metrics.recall_score(labels, preds_binary, average='weighted')
        f1_score = metrics.f1_score(labels, preds_binary, average='weighted')
        precision_all.append(precision)
        recall_all.append(recall)
        f1_score_all.append(f1_score)
    return sum(precision_all) / len(precision_all), sum(recall_all) / len(recall_all), sum(f1_score_all) / len(f1_score_all)


def gm_db(prob, buffer, labels, T=100):
    precision_all, recall_all, f1_score_all = [], [], []
    for t in range(T):
        masked_locs = []
        labels_all = []
        for idx, row in prob.iterrows():
            locs = buffer[idx]
            labels_all.append(labels[idx])
            locs = np.delete(locs, 0)
            x = random.choices(locs, weights=tuple(row.tolist()), k=1)[0]
            masked_locs.append(x)
        gdf = gdf2.iloc[masked_locs]
        points = np.array(np.stack([gdf.geometry.x, gdf.geometry.y], axis=1))
        db = DBSCAN(eps=500, min_samples=5).fit(points)
        preds = db.labels_
        preds_binary = [0 if i == -1 else 1 for i in preds]

        precision = metrics.precision_score(labels_all, preds_binary, average='weighted')
        recall = metrics.recall_score(labels_all, preds_binary, average='weighted')
        f1_score = metrics.f1_score(labels_all, preds_binary, average='weighted')
        precision_all.append(precision)
        recall_all.append(recall)
        f1_score_all.append(f1_score)
    return sum(precision_all) / len(precision_all), sum(recall_all) / len(recall_all), sum(f1_score_all) / len(f1_score_all)

# %%
import pandas as pd
import pickle
from sklearn.cluster import DBSCAN
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

X = np.array(np.stack([gdf1.geometry.x, gdf1.geometry.y], axis=1))
db = DBSCAN(eps=500, min_samples=5).fit(X)
labels = db.labels_
labels_binary = [0 if i == -1 else 1 for i in labels]

k_neighbors_all = [10, 20, 30]
eps_all = [0.1, 0.01, 0.001, 0.0001]
T = 100

with open('data/franklin/sols/franklin_db_all.csv', 'w') as fw:
    fw.write('method,eps,k,precision,recall,f1\n')
    fw.flush()
    
    for k_neighbors in k_neighbors_all:
        buffer = pickle.load(open('data/franklin/franklin_buff_k' + str(k_neighbors) + '.pickle', "rb"))
        db_random = random_db(buffer, labels_binary, T)
        fw.write('random,,' + str(k_neighbors) + ',' + str(db_random[0]) + ',' + str(db_random[1]) + ',' + str(db_random[2]) + '\n')
        print('db_random:', db_random[0], db_random[1], db_random[2])
        
        for eps in eps_all:
            prob = pd.read_csv('data/franklin/sols/franklin_prob_eps' + str(eps) + "_k" + str(k_neighbors) + '.csv', header=None, index_col=0)
            db_gm = gm_db(prob, buffer, labels_binary, T)
            fw.write('gm,' + str(eps) + ',' + str(k_neighbors) + ',' + str(db_gm[0]) + ',' + str(db_gm[1]) + ',' + str(db_gm[2]) + '\n')
            print('db_gm:', db_gm[0], db_gm[1], db_gm[2])
# Out:
# db_random: 0.9782313395024848 0.978051643192488 0.9781173252462707
# db_gm: 0.9862498941382577 0.9861521909233183 0.9861880043108853
# db_gm: 0.9839034746459698 0.9838028169014081 0.9838392297798748
# db_gm: 0.978925934707189 0.9787480438184665 0.9788125875736075
# db_gm: 0.9784058053223204 0.9782120500782469 0.9782809642965584
# db_random: 0.9704898865973273 0.9702053990610325 0.9703110153906417
# db_gm: 0.9862962502464236 0.9862050078247263 0.9862386050629278
# db_gm: 0.9806194134083459 0.9805633802816901 0.9805810780496619
# db_gm: 0.9738526977264977 0.9736189358372457 0.9737040814607077
# db_gm: 0.9714842764313957 0.9712773865414708 0.9713533466920978
# db_random: 0.9658658520104807 0.9656259780907664 0.9657200465476827
# db_gm: 0.9860883199941423 0.9859831735472507 0.9860209554581607
# db_gm: 0.975788194752191 0.9757159624413155 0.9757370606324326
# db_gm: 0.9717049295015613 0.9715082159624419 0.971583918676541
# db_gm: 0.9661990479658452 0.9659956964006261 0.9660749561193911
